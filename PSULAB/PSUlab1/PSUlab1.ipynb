# %%
pip install gym==0.17.3
# Out:
# ...
#      ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#      -- ------------------------------------- 0.1/1.6 MB 1.7 MB/s eta 0:00:01
#      ---------- ----------------------------- 0.4/1.6 MB 3.1 MB/s eta 0:00:01
#      ---------------------- ----------------- 0.9/1.6 MB 5.1 MB/s eta 0:00:01
#      -------------------------- ------------- 1.0/1.6 MB 6.0 MB/s eta 0:00:01
#      ---------------------------------------  1.5/1.6 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------- 1.6/1.6 MB 5.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...

# %%
import gymnasium as gym
import numpy as np
env=gym.make('Blackjack-v1', sab=True, render_mode="human")

o=env.reset()

# %%
print(o)
# Out:
# ((10, 1, 0), 0.0, False, False, {})

# %%
flag = 0
c1 = 0
c2 = 0
o=env.reset()
for i in range(100):
    """ if o[0][0] <= 21 and o[0][1] < o[0][0]:
    
    if o[0][0] > 21:
        flag=1 """
    
    action = env.action_space.sample()
    o=env.step(action)
    if action == 0 and o[1] == +1:
        print("win!")
        c1 += 1
    elif action == 0 and o[1] == -1:
        print("lose!")
        c2 += 1
    if o[1] < 0:
        o=env.reset()
    
print (c1/c2)
# Out:
# lose!
# win!
# win!
# win!
# win!
# win!
# win!
# lose!
# win!
# win!
# win!
# win!
# lose!
# lose!
# lose!
# lose!
# win!
# lose!
# lose!
# lose!
# win!
# win!
# win!
# lose!
# win!
# win!
# win!
# win!
# win!
# win!
# win!
# win!
# lose!
# win!
# win!
# win!
# win!
# win!
# win!
# lose!
# win!
# 2.4166666666666665

# %%
print(o)
# Out:
# ((20, 9, 0), {})
